# %% [markdown]
# ### Exercise1. Exploring a New Dataset
#
# 1. Load the Xarray tutorial dataset `rasm`.
# 2. Inspect the Dataset object and list all the variables and dimensions.
# 3. Select the `Tair` variable (air temperature).
# 4. Print the attributes, dimensions, and coordinates of `Tair`.

# %%
# %pip install xarray pooch
# Out:
# Collecting xarray
#   Downloading xarray-2025.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting pooch
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.26 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from xarray) (2.3.0)
# Requirement already satisfied: packaging>=24.1 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from xarray) (25.0)
# Requirement already satisfied: pandas>=2.2 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from xarray) (2.3.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from pooch) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from pooch) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from pandas>=2.2->xarray) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from pandas>=2.2->xarray) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from pandas>=2.2->xarray) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (2025.4.26)
# Downloading xarray-2025.8.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.1 MB/s eta 0:00:00a 0:00:01
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Installing collected packages: pooch, xarray
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [xarray]2m1/2 [xarray]
# Successfully installed pooch-1.8.2 xarray-2025.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

xr.set_options(keep_attrs=True, display_expand_data=False)
np.set_printoptions(threshold=10, edgeitems=2)

# %%
ds = xr.tutorial.open_dataset("rasm")
ds
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/times.py:545, in decode_cf_datetime(num_dates, units, calendar, use_cftime, time_unit)
#     544 try:
# --> 545     dates = _decode_datetime_with_pandas(
#     546         flat_num_dates, units, calendar, time_unit
#     547     )
#     548 except (KeyError, OutOfBoundsDatetime, OutOfBoundsTimedelta, OverflowError):
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/times.py:461, in _decode_datetime_with_pandas(flat_num_dates, units, calendar, time_resolution)
#     460 if not _is_standard_calendar(calendar):
# --> 461     raise OutOfBoundsDatetime(
#     462         f"Cannot decode times from a non-standard calendar, {calendar!r}, using "
#     463         "pandas."
#     464     )
#     466 # Work around pandas.to_timedelta issue with dtypes smaller than int64 and
#     467 # NumPy 2.0 by casting all int and uint data to int64 and uint64,
#     468 # respectively. See https://github.com/pandas-dev/pandas/issues/56996 for
#     469 # more details.
#
# OutOfBoundsDatetime: Cannot decode times from a non-standard calendar, 'noleap', using pandas.
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/utils.py:1305, in attempt_import(module)
#    1304 try:
# -> 1305     return importlib.import_module(module)
#    1306 except ImportError as e:
#
# File ~/miniforge3/envs/geo/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'cftime'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/times.py:337, in _decode_cf_datetime_dtype(data, units, calendar, use_cftime, time_unit)
#     336 try:
# --> 337     result = decode_cf_datetime(
#     338         example_value, units, calendar, use_cftime, time_unit
#     339     )
#     340 except Exception as err:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/times.py:549, in decode_cf_datetime(num_dates, units, calendar, use_cftime, time_unit)
#     548 except (KeyError, OutOfBoundsDatetime, OutOfBoundsTimedelta, OverflowError):
# --> 549     dates = _decode_datetime_with_cftime(
#     550         flat_num_dates.astype(float), units, calendar
#     551     )
#     552     # retrieve cftype
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/times.py:362, in _decode_datetime_with_cftime(num_dates, units, calendar)
#     361 else:
# --> 362     cftime = attempt_import("cftime")
#     363 if num_dates.size > 0:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/utils.py:1307, in attempt_import(module)
#    1306 except ImportError as e:
# -> 1307     raise ImportError(
#    1308         f"The {install_name} package is required {reason}"
#    1309         " but could not be imported."
#    1310         " Please install it with your package manager (e.g. conda or pip)."
#    1311     ) from e
#
# ImportError: The cftime package is required for working with non-standard calendars but could not be imported. Please install it with your package manager (e.g. conda or pip).
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/conventions.py:412, in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     411 try:
# --> 412     new_vars[k] = decode_cf_variable(
#     413         k,
#     414         v,
#     415         concat_characters=_item_or_default(concat_characters, k, True),
#     416         mask_and_scale=_item_or_default(mask_and_scale, k, True),
#     417         decode_times=_item_or_default(decode_times, k, True),
#     418         stack_char_dim=stack_char_dim,
#     419         use_cftime=_item_or_default(use_cftime, k, None),
#     420         decode_timedelta=_item_or_default(decode_timedelta, k, None),
#     421     )
#     422 except Exception as e:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/conventions.py:239, in decode_cf_variable(name, var, concat_characters, mask_and_scale, decode_times, decode_endianness, stack_char_dim, use_cftime, decode_timedelta)
#     230         raise TypeError(
#     231             "Usage of 'use_cftime' as a kwarg is not allowed "
#     232             "if a 'CFDatetimeCoder' instance is passed to "
#    (...)    237             "    ds = xr.open_dataset(decode_times=time_coder)\n",
#     238         )
# --> 239     var = decode_times.decode(var, name=name)
#     241 if decode_endianness and not var.dtype.isnative:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/times.py:1391, in CFDatetimeCoder.decode(self, variable, name)
#    1390 calendar = pop_to(attrs, encoding, "calendar")
# -> 1391 dtype = _decode_cf_datetime_dtype(
#    1392     data, units, calendar, self.use_cftime, self.time_unit
#    1393 )
#    1394 transform = partial(
#    1395     decode_cf_datetime,
#    1396     units=units,
#    (...)   1399     time_unit=self.time_unit,
#    1400 )
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/times.py:349, in _decode_cf_datetime_dtype(data, units, calendar, use_cftime, time_unit)
#     344     msg = (
#     345         f"unable to decode time units {units!r} with {calendar_msg!r}. Try "
#     346         "opening your dataset with decode_times=False or installing cftime "
#     347         "if it is not installed."
#     348     )
# --> 349     raise ValueError(msg) from err
#     350 else:
#
# ValueError: unable to decode time units 'days since 0001-01-01' with "calendar 'noleap'". Try opening your dataset with decode_times=False or installing cftime if it is not installed.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ds = xr.tutorial.open_dataset("rasm")
#       2 ds
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/tutorial.py:170, in open_dataset(name, cache, cache_dir, engine, **kws)
#     166 # retrieve the file
#     167 filepath = pooch.retrieve(
#     168     url=url, known_hash=None, path=cache_dir, downloader=downloader
#     169 )
# --> 170 ds = _open_dataset(filepath, engine=engine, **kws)
#     171 if not cache:
#     172     ds = ds.load()
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/backends/api.py:750, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     738 decoders = _resolve_decoders_kwargs(
#     739     decode_cf,
#     740     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)    746     decode_coords=decode_coords,
#     747 )
#     749 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 750 backend_ds = backend.open_dataset(
#     751     filename_or_obj,
#     752     drop_variables=drop_variables,
#     753     **decoders,
#     754     **kwargs,
#     755 )
#     756 ds = _dataset_from_backend_dataset(
#     757     backend_ds,
#     758     filename_or_obj,
#    (...)    769     **kwargs,
#     770 )
#     771 return ds
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/backends/scipy_.py:381, in ScipyBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, mode, format, group, mmap, lock)
#     379 store_entrypoint = StoreBackendEntrypoint()
#     380 with close_on_error(store):
# --> 381     ds = store_entrypoint.open_dataset(
#     382         store,
#     383         mask_and_scale=mask_and_scale,
#     384         decode_times=decode_times,
#     385         concat_characters=concat_characters,
#     386         decode_coords=decode_coords,
#     387         drop_variables=drop_variables,
#     388         use_cftime=use_cftime,
#     389         decode_timedelta=decode_timedelta,
#     390     )
#     391 return ds
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/backends/store.py:45, in StoreBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, set_indexes, use_cftime, decode_timedelta)
#      42 vars, attrs = filename_or_obj.load()
#      43 encoding = filename_or_obj.get_encoding()
# ---> 45 vars, attrs, coord_names = conventions.decode_cf_variables(
#      46     vars,
#      47     attrs,
#      48     mask_and_scale=mask_and_scale,
#      49     decode_times=decode_times,
#      50     concat_characters=concat_characters,
#      51     decode_coords=decode_coords,
#      52     drop_variables=drop_variables,
#      53     use_cftime=use_cftime,
#      54     decode_timedelta=decode_timedelta,
#      55 )
#      57 # split data and coordinate variables (promote dimension coordinates)
#      58 data_vars = {}
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/conventions.py:423, in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     412     new_vars[k] = decode_cf_variable(
#     413         k,
#     414         v,
#    (...)    420         decode_timedelta=_item_or_default(decode_timedelta, k, None),
#     421     )
#     422 except Exception as e:
# --> 423     raise type(e)(f"Failed to decode variable {k!r}: {e}") from e
#     424 if decode_coords in [True, "coordinates", "all"]:
#     425     var_attrs = new_vars[k].attrs
#
# ValueError: Failed to decode variable 'time': unable to decode time units 'days since 0001-01-01' with "calendar 'noleap'". Try opening your dataset with decode_times=False or installing cftime if it is not installed.

# %%
ds = xr.tutorial.open_dataset("rasm", decode_times=False)
ds
# Out:
# <xarray.Dataset> Size: 17MB
# Dimensions:  (time: 36, y: 205, x: 275)
# Coordinates:
#   * time     (time) float64 288B 7.226e+05 7.226e+05 ... 7.236e+05 7.237e+05
#     xc       (y, x) float64 451kB ...
#     yc       (y, x) float64 451kB ...
# Dimensions without coordinates: y, x
# Data variables:
#     Tair     (time, y, x) float64 16MB ...
# Attributes:
#     title:                     /workspace/jhamman/processed/R1002RBRxaaa01a/l...
#     institution:               U.W.
#     source:                    RACM R1002RBRxaaa01a
#     output_frequency:          daily
#     output_mode:               averaged
#     convention:                CF-1.4
#     references:                Based on the initial model of Liang et al., 19...
#     comment:                   Output from the Variable Infiltration Capacity...
#     nco_openmp_thread_number:  1
#     NCO:                       netCDF Operators version 4.7.9 (Homepage = htt...
#     history:                   Fri Aug  7 17:57:38 2020: ncatted -a bounds,,d...

# %%
ds.dims
# Out:
# FrozenMappingWarningOnValuesAccess({'time': 36, 'y': 205, 'x': 275})

# %%
ds.var
# Out:
# <bound method DatasetAggregations.var of <xarray.Dataset> Size: 17MB
# Dimensions:  (time: 36, y: 205, x: 275)
# Coordinates:
#   * time     (time) float64 288B 7.226e+05 7.226e+05 ... 7.236e+05 7.237e+05
#     xc       (y, x) float64 451kB ...
#     yc       (y, x) float64 451kB ...
# Dimensions without coordinates: y, x
# Data variables:
#     Tair     (time, y, x) float64 16MB ...
# Attributes:
#     title:                     /workspace/jhamman/processed/R1002RBRxaaa01a/l...
#     institution:               U.W.
#     source:                    RACM R1002RBRxaaa01a
#     output_frequency:          daily
#     output_mode:               averaged
#     convention:                CF-1.4
#     references:                Based on the initial model of Liang et al., 19...
#     comment:                   Output from the Variable Infiltration Capacity...
#     nco_openmp_thread_number:  1
#     NCO:                       netCDF Operators version 4.7.9 (Homepage = htt...
#     history:                   Fri Aug  7 17:57:38 2020: ncatted -a bounds,,d...>

# %%
air_temp = ds['Tair']

# %%
air_temp
# Out:
# <xarray.DataArray 'Tair' (time: 36, y: 205, x: 275)> Size: 16MB
# [2029500 values with dtype=float64]
# Coordinates:
#   * time     (time) float64 288B 7.226e+05 7.226e+05 ... 7.236e+05 7.237e+05
#     xc       (y, x) float64 451kB ...
#     yc       (y, x) float64 451kB ...
# Dimensions without coordinates: y, x
# Attributes:
#     units:           C
#     long_name:       Surface air temperature
#     type_preferred:  double
#     time_rep:        instantaneous

# %%
air_temp.attrs
# Out:
# {'units': 'C',
#  'long_name': 'Surface air temperature',
#  'type_preferred': 'double',
#  'time_rep': 'instantaneous'}

# %%
air_temp.dims
# Out:
# ('time', 'y', 'x')

# %%
air_temp.coords
# Out:
# Coordinates:
#   * time     (time) float64 288B 7.226e+05 7.226e+05 ... 7.236e+05 7.237e+05
#     xc       (y, x) float64 451kB ...
#     yc       (y, x) float64 451kB ...

# %% [markdown]
# ### Exercise 2: Data Selection and Indexing
#
# 1. Select a subset of the Tair data for the date 1980-07-01 and latitude 70.0.
# 2. Create a time slice for the entire latitude range between January and March of 1980.
# 3. Plot the selected time slice as a line plot.

# %%
sel_temp = air_temp.sel(time = '1980-07-01', y = 70.0)
sel_temp
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sel_temp = air_temp.sel(time = '1980-07-01', y = 70.0)
#       2 sel_temp
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/dataarray.py:1716, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1600 def sel(
#    1601     self,
#    1602     indexers: Mapping[Any, Any] | None = None,
#    (...)   1606     **indexers_kwargs: Any,
#    1607 ) -> Self:
#    1608     """Return a new DataArray whose data is given by selecting index
#    1609     labels along the specified dimension(s).
#    1610
#    (...)   1714     Dimensions without coordinates: points
#    1715     """
# -> 1716     ds = self._to_temp_dataset().sel(
#    1717         indexers=indexers,
#    1718         drop=drop,
#    1719         method=method,
#    1720         tolerance=tolerance,
#    1721         **indexers_kwargs,
#    1722     )
#    1723     return self._from_temp_dataset(ds)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/dataset.py:2991, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2923 """Returns a new dataset with each array indexed by tick labels
#    2924 along the specified dimension(s).
#    2925
#    (...)   2988
#    2989 """
#    2990 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2991 query_results = map_index_queries(
#    2992     self, indexers=indexers, method=method, tolerance=tolerance
#    2993 )
#    2995 if drop:
#    2996     no_scalar_variables = {}
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/indexing.py:201, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     199         results.append(IndexSelResult(labels))
#     200     else:
# --> 201         results.append(index.sel(labels, **options))
#     203 merged = merge_sel_results(results)
#     205 # drop dimension coordinates found in dimension indexers
#     206 # (also drop multi-index if any)
#     207 # (.sel() already ensures alignment)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/indexes.py:842, in PandasIndex.sel(self, labels, method, tolerance)
#     837     raise ValueError(
#     838         "cannot use a dict-like object for selection on "
#     839         "a dimension that does not have a MultiIndex"
#     840     )
#     841 else:
# --> 842     label_array = normalize_label(label, dtype=self.coord_dtype)
#     843     if label_array.ndim == 0:
#     844         label_value = as_scalar(label_array)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/indexes.py:615, in normalize_label(value, dtype)
#     609     value = _asarray_tuplesafe(value)
#     610 if dtype is not None and dtype.kind == "f" and value.dtype.kind != "b":
#     611     # pd.Index built from coordinate with float precision != 64
#     612     # see https://github.com/pydata/xarray/pull/3153 for details
#     613     # bypass coercing dtype for boolean indexers (ignore index)
#     614     # see https://github.com/pydata/xarray/issues/5727
# --> 615     value = np.asarray(value, dtype=dtype)
#     616 return value
#
# ValueError: could not convert string to float: np.str_('1980-07-01')

# %%
print (air_temp ['time'])
# Out:
# <xarray.DataArray 'time' (time: 36)> Size: 288B
# 7.226e+05 7.226e+05 7.227e+05 7.227e+05 ... 7.236e+05 7.236e+05 7.237e+05
# Coordinates:
#   * time     (time) float64 288B 7.226e+05 7.226e+05 ... 7.236e+05 7.237e+05
# Attributes:
#     long_name:       time
#     type_preferred:  int
#     units:           days since 0001-01-01
#     calendar:        noleap

# %%
# the time dimension is in strings and need to be decoded.
ds = xr.decode_cf (ds, use_cftime = True)
# Out:
# /var/folders/xv/2scx9tld4jj79kgrbb22ln480000gn/T/ipykernel_5917/2829929647.py:2: DeprecationWarning: Usage of 'use_cftime' as a kwarg is deprecated. Please pass a 'CFDatetimeCoder' instance initialized with 'use_cftime' to the 'decode_times' kwarg instead.
# Example usage:
#     time_coder = xr.coders.CFDatetimeCoder(use_cftime=True)
#     ds = xr.open_dataset(decode_times=time_coder)
#
#   ds = xr.decode_cf (ds, use_cftime = True)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/utils.py:1305, in attempt_import(module)
#    1304 try:
# -> 1305     return importlib.import_module(module)
#    1306 except ImportError as e:
#
# File ~/miniforge3/envs/geo/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'cftime'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/times.py:337, in _decode_cf_datetime_dtype(data, units, calendar, use_cftime, time_unit)
#     336 try:
# --> 337     result = decode_cf_datetime(
#     338         example_value, units, calendar, use_cftime, time_unit
#     339     )
#     340 except Exception as err:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/times.py:585, in decode_cf_datetime(num_dates, units, calendar, use_cftime, time_unit)
#     584 elif use_cftime:
# --> 585     dates = _decode_datetime_with_cftime(flat_num_dates, units, calendar)
#     586 else:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/times.py:362, in _decode_datetime_with_cftime(num_dates, units, calendar)
#     361 else:
# --> 362     cftime = attempt_import("cftime")
#     363 if num_dates.size > 0:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/utils.py:1307, in attempt_import(module)
#    1306 except ImportError as e:
# -> 1307     raise ImportError(
#    1308         f"The {install_name} package is required {reason}"
#    1309         " but could not be imported."
#    1310         " Please install it with your package manager (e.g. conda or pip)."
#    1311     ) from e
#
# ImportError: The cftime package is required for working with non-standard calendars but could not be imported. Please install it with your package manager (e.g. conda or pip).
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/conventions.py:412, in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     411 try:
# --> 412     new_vars[k] = decode_cf_variable(
#     413         k,
#     414         v,
#     415         concat_characters=_item_or_default(concat_characters, k, True),
#     416         mask_and_scale=_item_or_default(mask_and_scale, k, True),
#     417         decode_times=_item_or_default(decode_times, k, True),
#     418         stack_char_dim=stack_char_dim,
#     419         use_cftime=_item_or_default(use_cftime, k, None),
#     420         decode_timedelta=_item_or_default(decode_timedelta, k, None),
#     421     )
#     422 except Exception as e:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/conventions.py:239, in decode_cf_variable(name, var, concat_characters, mask_and_scale, decode_times, decode_endianness, stack_char_dim, use_cftime, decode_timedelta)
#     230         raise TypeError(
#     231             "Usage of 'use_cftime' as a kwarg is not allowed "
#     232             "if a 'CFDatetimeCoder' instance is passed to "
#    (...)    237             "    ds = xr.open_dataset(decode_times=time_coder)\n",
#     238         )
# --> 239     var = decode_times.decode(var, name=name)
#     241 if decode_endianness and not var.dtype.isnative:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/times.py:1391, in CFDatetimeCoder.decode(self, variable, name)
#    1390 calendar = pop_to(attrs, encoding, "calendar")
# -> 1391 dtype = _decode_cf_datetime_dtype(
#    1392     data, units, calendar, self.use_cftime, self.time_unit
#    1393 )
#    1394 transform = partial(
#    1395     decode_cf_datetime,
#    1396     units=units,
#    (...)   1399     time_unit=self.time_unit,
#    1400 )
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/times.py:349, in _decode_cf_datetime_dtype(data, units, calendar, use_cftime, time_unit)
#     344     msg = (
#     345         f"unable to decode time units {units!r} with {calendar_msg!r}. Try "
#     346         "opening your dataset with decode_times=False or installing cftime "
#     347         "if it is not installed."
#     348     )
# --> 349     raise ValueError(msg) from err
#     350 else:
#
# ValueError: unable to decode time units 'days since 0001-01-01' with "calendar 'noleap'". Try opening your dataset with decode_times=False or installing cftime if it is not installed.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 # the time dimension is in strings and need to be decoded.
# ----> 2 ds = xr.decode_cf (ds, use_cftime = True)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/conventions.py:584, in decode_cf(obj, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     581 else:
#     582     raise TypeError("can only decode Dataset or DataStore objects")
# --> 584 vars, attrs, coord_names = decode_cf_variables(
#     585     vars,
#     586     attrs,
#     587     concat_characters,
#     588     mask_and_scale,
#     589     decode_times,
#     590     decode_coords,
#     591     drop_variables=drop_variables,
#     592     use_cftime=use_cftime,
#     593     decode_timedelta=decode_timedelta,
#     594 )
#     595 ds = Dataset(vars, attrs=attrs)
#     596 ds = ds.set_coords(coord_names.union(extra_coords).intersection(vars))
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/conventions.py:423, in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     412     new_vars[k] = decode_cf_variable(
#     413         k,
#     414         v,
#    (...)    420         decode_timedelta=_item_or_default(decode_timedelta, k, None),
#     421     )
#     422 except Exception as e:
# --> 423     raise type(e)(f"Failed to decode variable {k!r}: {e}") from e
#     424 if decode_coords in [True, "coordinates", "all"]:
#     425     var_attrs = new_vars[k].attrs
#
# ValueError: Failed to decode variable 'time': unable to decode time units 'days since 0001-01-01' with "calendar 'noleap'". Try opening your dataset with decode_times=False or installing cftime if it is not installed.

# %%
# %pip install cftime
# Out:
# Collecting cftime
#   Downloading cftime-1.6.4.post1-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Requirement already satisfied: numpy>1.13.3 in /Users/shazia_manuawar/miniforge3/envs/geo/lib/python3.11/site-packages (from cftime) (2.3.0)
# Downloading cftime-1.6.4.post1-cp311-cp311-macosx_11_0_arm64.whl (214 kB)
# Installing collected packages: cftime
# Successfully installed cftime-1.6.4.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
ds = xr.tutorial.open_dataset("rasm")
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ds = xr.tutorial.open_dataset("rasm")
#       2 ds
#
# NameError: name 'xr' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

xr.set_options(keep_attrs=True, display_expand_data=False)
np.set_printoptions(threshold=10, edgeitems=2)

# %%
ds = xr.tutorial.open_dataset("rasm")
ds
# Out:
# <xarray.Dataset> Size: 17MB
# Dimensions:  (time: 36, y: 205, x: 275)
# Coordinates:
#   * time     (time) object 288B 1980-09-16 12:00:00 ... 1983-08-17 00:00:00
#     xc       (y, x) float64 451kB ...
#     yc       (y, x) float64 451kB ...
# Dimensions without coordinates: y, x
# Data variables:
#     Tair     (time, y, x) float64 16MB ...
# Attributes:
#     title:                     /workspace/jhamman/processed/R1002RBRxaaa01a/l...
#     institution:               U.W.
#     source:                    RACM R1002RBRxaaa01a
#     output_frequency:          daily
#     output_mode:               averaged
#     convention:                CF-1.4
#     references:                Based on the initial model of Liang et al., 19...
#     comment:                   Output from the Variable Infiltration Capacity...
#     nco_openmp_thread_number:  1
#     NCO:                       netCDF Operators version 4.7.9 (Homepage = htt...
#     history:                   Fri Aug  7 17:57:38 2020: ncatted -a bounds,,d...

# %%
air_temp = ds ['Tair']

# %%
sel_temp = air_temp.sel (time = '1980-07-01', y = 70.0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/cftimeindex.py:380, in CFTimeIndex._get_string_slice(self, key)
#     379 try:
# --> 380     loc = self._partial_date_slice(resolution, parsed)
#     381 except KeyError as err:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/cftimeindex.py:365, in CFTimeIndex._partial_date_slice(self, resolution, parsed)
#     360 if len(times) and (
#     361     (start < times[0] and end < times[0])
#     362     or (start > times[-1] and end > times[-1])
#     363 ):
#     364     # we are out of range
# --> 365     raise KeyError
#     367 # a monotonic (sorted) series can be sliced
#
# KeyError:
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/indexes.py:861, in PandasIndex.sel(self, labels, method, tolerance)
#     860 try:
# --> 861     indexer = self.index.get_loc(label_value)
#     862 except KeyError as e:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/cftimeindex.py:414, in CFTimeIndex.get_loc(self, key)
#     413 if isinstance(key, str):
# --> 414     return self._get_string_slice(key)
#     415 else:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/cftimeindex.py:382, in CFTimeIndex._get_string_slice(self, key)
#     381 except KeyError as err:
# --> 382     raise KeyError(key) from err
#     383 return loc
#
# KeyError: '1980-07-01'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sel_temp = air_temp.sel (time = '1980-07-01', y = 70.0)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/dataarray.py:1716, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1600 def sel(
#    1601     self,
#    1602     indexers: Mapping[Any, Any] | None = None,
#    (...)   1606     **indexers_kwargs: Any,
#    1607 ) -> Self:
#    1608     """Return a new DataArray whose data is given by selecting index
#    1609     labels along the specified dimension(s).
#    1610
#    (...)   1714     Dimensions without coordinates: points
#    1715     """
# -> 1716     ds = self._to_temp_dataset().sel(
#    1717         indexers=indexers,
#    1718         drop=drop,
#    1719         method=method,
#    1720         tolerance=tolerance,
#    1721         **indexers_kwargs,
#    1722     )
#    1723     return self._from_temp_dataset(ds)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/dataset.py:2991, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2923 """Returns a new dataset with each array indexed by tick labels
#    2924 along the specified dimension(s).
#    2925
#    (...)   2988
#    2989 """
#    2990 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2991 query_results = map_index_queries(
#    2992     self, indexers=indexers, method=method, tolerance=tolerance
#    2993 )
#    2995 if drop:
#    2996     no_scalar_variables = {}
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/indexing.py:201, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     199         results.append(IndexSelResult(labels))
#     200     else:
# --> 201         results.append(index.sel(labels, **options))
#     203 merged = merge_sel_results(results)
#     205 # drop dimension coordinates found in dimension indexers
#     206 # (also drop multi-index if any)
#     207 # (.sel() already ensures alignment)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/indexes.py:863, in PandasIndex.sel(self, labels, method, tolerance)
#     861             indexer = self.index.get_loc(label_value)
#     862         except KeyError as e:
# --> 863             raise KeyError(
#     864                 f"not all values found in index {coord_name!r}. "
#     865                 "Try setting the `method` keyword argument (example: method='nearest')."
#     866             ) from e
#     868 elif label_array.dtype.kind == "b":
#     869     indexer = label_array
#
# KeyError: "not all values found in index 'time'. Try setting the `method` keyword argument (example: method='nearest')."

# %%
print (air_temp.time.values)
# Out:
# [cftime.DatetimeNoLeap(1980, 9, 16, 12, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1980, 10, 17, 0, 0, 0, 0, has_year_zero=True) ...
#  cftime.DatetimeNoLeap(1983, 7, 17, 0, 0, 0, 0, has_year_zero=True)
#  cftime.DatetimeNoLeap(1983, 8, 17, 0, 0, 0, 0, has_year_zero=True)]

# %%
sel_temp = air_temp.sel (time = '1980-07-01', y = 70.0, method = 'nearest')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sel_temp = air_temp.sel (time = '1980-07-01', y = 70.0, method = 'nearest')
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/dataarray.py:1716, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1600 def sel(
#    1601     self,
#    1602     indexers: Mapping[Any, Any] | None = None,
#    (...)   1606     **indexers_kwargs: Any,
#    1607 ) -> Self:
#    1608     """Return a new DataArray whose data is given by selecting index
#    1609     labels along the specified dimension(s).
#    1610
#    (...)   1714     Dimensions without coordinates: points
#    1715     """
# -> 1716     ds = self._to_temp_dataset().sel(
#    1717         indexers=indexers,
#    1718         drop=drop,
#    1719         method=method,
#    1720         tolerance=tolerance,
#    1721         **indexers_kwargs,
#    1722     )
#    1723     return self._from_temp_dataset(ds)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/dataset.py:2991, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2923 """Returns a new dataset with each array indexed by tick labels
#    2924 along the specified dimension(s).
#    2925
#    (...)   2988
#    2989 """
#    2990 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2991 query_results = map_index_queries(
#    2992     self, indexers=indexers, method=method, tolerance=tolerance
#    2993 )
#    2995 if drop:
#    2996     no_scalar_variables = {}
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/indexing.py:193, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     190     options = {"method": method, "tolerance": tolerance}
#     192 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "map_index_queries")
# --> 193 grouped_indexers = group_indexers_by_index(obj, indexers, options)
#     195 results = []
#     196 for index, labels in grouped_indexers:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/indexing.py:159, in group_indexers_by_index(obj, indexers, options)
#     154     raise KeyError(
#     155         f"{key!r} is not a valid dimension or coordinate for "
#     156         f"{obj.__class__.__name__} with dimensions {obj.dims!r}"
#     157     )
#     158 elif len(options):
# --> 159     raise ValueError(
#     160         f"cannot supply selection options {options!r} for dimension {key!r}"
#     161         "that has no associated coordinate or index"
#     162     )
#     163 else:
#     164     # key is a dimension without a "dimension-coordinate"
#     165     # failback to location-based selection
#     166     # TODO: depreciate this implicit behavior and suggest using isel instead?
#     167     unique_indexes[None] = None
#
# ValueError: cannot supply selection options {'method': 'nearest', 'tolerance': None} for dimension 'y'that has no associated coordinate or index

# %%
sel_temp = air_temp.sel (time = '1980-07-01', yc = 70.0, method = 'nearest')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sel_temp = air_temp.sel (time = '1980-07-01', yc = 70.0, method = 'nearest')
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/dataarray.py:1716, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1600 def sel(
#    1601     self,
#    1602     indexers: Mapping[Any, Any] | None = None,
#    (...)   1606     **indexers_kwargs: Any,
#    1607 ) -> Self:
#    1608     """Return a new DataArray whose data is given by selecting index
#    1609     labels along the specified dimension(s).
#    1610
#    (...)   1714     Dimensions without coordinates: points
#    1715     """
# -> 1716     ds = self._to_temp_dataset().sel(
#    1717         indexers=indexers,
#    1718         drop=drop,
#    1719         method=method,
#    1720         tolerance=tolerance,
#    1721         **indexers_kwargs,
#    1722     )
#    1723     return self._from_temp_dataset(ds)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/dataset.py:2991, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2923 """Returns a new dataset with each array indexed by tick labels
#    2924 along the specified dimension(s).
#    2925
#    (...)   2988
#    2989 """
#    2990 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2991 query_results = map_index_queries(
#    2992     self, indexers=indexers, method=method, tolerance=tolerance
#    2993 )
#    2995 if drop:
#    2996     no_scalar_variables = {}
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/indexing.py:193, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     190     options = {"method": method, "tolerance": tolerance}
#     192 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "map_index_queries")
# --> 193 grouped_indexers = group_indexers_by_index(obj, indexers, options)
#     195 results = []
#     196 for index, labels in grouped_indexers:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/indexing.py:152, in group_indexers_by_index(obj, indexers, options)
#     150     grouped_indexers[index_id][key] = label
#     151 elif key in obj.coords:
# --> 152     raise KeyError(f"no index found for coordinate {key!r}")
#     153 elif key not in obj.dims:
#     154     raise KeyError(
#     155         f"{key!r} is not a valid dimension or coordinate for "
#     156         f"{obj.__class__.__name__} with dimensions {obj.dims!r}"
#     157     )
#
# KeyError: "no index found for coordinate 'yc'"

# %%
print (air_temp.dims)
print (air_temp.coords)
# Out:
# ('time', 'y', 'x')
# Coordinates:
#   * time     (time) object 288B 1980-09-16 12:00:00 ... 1983-08-17 00:00:00
#     xc       (y, x) float64 451kB ...
#     yc       (y, x) float64 451kB ...

# %%
point = air_temp.sel(
    time="1980-09-16 12:00:00",
    method="nearest"
).sel_points(
    yc=70.0,
    method="nearest"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 point = air_temp.sel(
#       2     time="1980-09-16 12:00:00",
#       3     method="nearest"
#       4 ).sel_points(
#       5     yc=70.0,
#       6     method="nearest"
#       7 )
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/dataarray.py:1716, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1600 def sel(
#    1601     self,
#    1602     indexers: Mapping[Any, Any] | None = None,
#    (...)   1606     **indexers_kwargs: Any,
#    1607 ) -> Self:
#    1608     """Return a new DataArray whose data is given by selecting index
#    1609     labels along the specified dimension(s).
#    1610
#    (...)   1714     Dimensions without coordinates: points
#    1715     """
# -> 1716     ds = self._to_temp_dataset().sel(
#    1717         indexers=indexers,
#    1718         drop=drop,
#    1719         method=method,
#    1720         tolerance=tolerance,
#    1721         **indexers_kwargs,
#    1722     )
#    1723     return self._from_temp_dataset(ds)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/dataset.py:2991, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2923 """Returns a new dataset with each array indexed by tick labels
#    2924 along the specified dimension(s).
#    2925
#    (...)   2988
#    2989 """
#    2990 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2991 query_results = map_index_queries(
#    2992     self, indexers=indexers, method=method, tolerance=tolerance
#    2993 )
#    2995 if drop:
#    2996     no_scalar_variables = {}
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/indexing.py:201, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     199         results.append(IndexSelResult(labels))
#     200     else:
# --> 201         results.append(index.sel(labels, **options))
#     203 merged = merge_sel_results(results)
#     205 # drop dimension coordinates found in dimension indexers
#     206 # (also drop multi-index if any)
#     207 # (.sel() already ensures alignment)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/indexes.py:856, in PandasIndex.sel(self, labels, method, tolerance)
#     854     indexer = self.index.get_loc(label_value)
#     855 elif method is not None:
# --> 856     indexer = get_indexer_nd(self.index, label_array, method, tolerance)
#     857     if np.any(indexer < 0):
#     858         raise KeyError(f"not all values found in index {coord_name!r}")
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/core/indexes.py:631, in get_indexer_nd(index, labels, method, tolerance)
#     629 if flat_labels.dtype == "float16":
#     630     flat_labels = flat_labels.astype("float64")
# --> 631 flat_indexer = index.get_indexer(flat_labels, method=method, tolerance=tolerance)
#     632 indexer = flat_indexer.reshape(labels.shape)
#     633 return indexer
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/pandas/core/indexes/base.py:3960, in Index.get_indexer(self, target, method, limit, tolerance)
#    3955     target = target.astype(dtype, copy=False)
#    3956     return this._get_indexer(
#    3957         target, method=method, limit=limit, tolerance=tolerance
#    3958     )
# -> 3960 return self._get_indexer(target, method, limit, tolerance)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/pandas/core/indexes/base.py:3975, in Index._get_indexer(self, target, method, limit, tolerance)
#    3973     indexer = self._get_fill_indexer(target, method, limit, tolerance)
#    3974 elif method == "nearest":
# -> 3975     indexer = self._get_nearest_indexer(target, limit, tolerance)
#    3976 else:
#    3977     if target._is_multi and self._is_multi:
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/xarray/coding/cftimeindex.py:387, in CFTimeIndex._get_nearest_indexer(self, target, limit, tolerance)
#     385 def _get_nearest_indexer(self, target, limit, tolerance):
#     386     """Adapted from pandas.Index._get_nearest_indexer"""
# --> 387     left_indexer = self.get_indexer(target, "pad", limit=limit)
#     388     right_indexer = self.get_indexer(target, "backfill", limit=limit)
#     389     left_distances = abs(self.values[left_indexer] - target.values)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/pandas/core/indexes/base.py:3960, in Index.get_indexer(self, target, method, limit, tolerance)
#    3955     target = target.astype(dtype, copy=False)
#    3956     return this._get_indexer(
#    3957         target, method=method, limit=limit, tolerance=tolerance
#    3958     )
# -> 3960 return self._get_indexer(target, method, limit, tolerance)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/pandas/core/indexes/base.py:3973, in Index._get_indexer(self, target, method, limit, tolerance)
#    3970     tolerance = self._convert_tolerance(tolerance, target)
#    3972 if method in ["pad", "backfill"]:
# -> 3973     indexer = self._get_fill_indexer(target, method, limit, tolerance)
#    3974 elif method == "nearest":
#    3975     indexer = self._get_nearest_indexer(target, limit, tolerance)
#
# File ~/miniforge3/envs/geo/lib/python3.11/site-packages/pandas/core/indexes/base.py:4090, in Index._get_fill_indexer(self, target, method, limit, tolerance)
#    4087     raise NotImplementedError
#    4089 if method == "pad":
# -> 4090     indexer = libalgos.pad(own_values, target_values, limit=limit)
#    4091 else:
#    4092     # i.e. "backfill"
#    4093     indexer = libalgos.backfill(own_values, target_values, limit=limit)
#
# File pandas/_libs/algos.pyx:585, in pandas._libs.algos.pad()
#
# TypeError: '<' not supported between instances of 'str' and 'cftime._cftime.DatetimeNoLeap'
